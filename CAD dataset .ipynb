# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("CAD.csv")
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ...    K   Na    WBC Lymph Neut  PLT EF-TTE  Region RWMA  \
# 0            0   0  ...  4.7  141   5700    39   52  261     50            0
# 1            0   0  ...  4.7  156   7700    38   55  165     40            4
# 2            0   0  ...  4.7  139   7400    38   60  230     40            2
# 3            0   0  ...  4.4  142  13000    18   72  742     55            0
# 4            0   0  ...  4.0  140   9200    55   39  274     50            0
# ..         ...  ..  ...  ...  ...    ...   ...  ...  ...    ...          ...
# 298          0   0  ...  4.8  146   8500    34   58  251     45            0
# 299          0   0  ...  4.0  139  11400    16   80  377     40            0
# 300          0   1  ...  4.0  140   9000    35   55  279     55            0
# 301          0   0  ...  3.8  141   3800    48   40  208     55            0
# 302          0   0  ...  4.4  147   6000    32   55  302     55            0
#
#         VHD    Cath
# 0         N     Cad
# 1         N     Cad
# 2      mild     Cad
# 3    Severe  Normal
# 4    Severe  Normal
# ..      ...     ...
# 298       N     Cad
# 299    mild  Normal
# 300       N  Normal
# 301       N  Normal
# 302       N     Cad
#
# [303 rows x 55 columns]

# %%
df.head().T
# Out:
#                                0          1          2          3          4
# Age                           53         67         54         66         50
# Weight                        90         70         54         67         87
# Length                       175        157        164        158        153
# Sex                         Male      Fmale       Male      Fmale      Fmale
# BMI                    29.387755  28.398718  20.077335  26.838648  37.165193
# DM                             0          0          0          0          0
# HTN                            1          1          0          1          1
# Current Smoker                 1          0          1          0          0
# EX-Smoker                      0          0          0          0          0
# FH                             0          0          0          0          0
# Obesity                        Y          Y          N          Y          Y
# CRF                            N          N          N          N          N
# CVA                            N          N          N          N          N
# Airway disease                 N          N          N          N          N
# Thyroid Disease                N          N          N          N          N
# CHF                            N          N          N          N          N
# DLP                            Y          N          N          N          N
# BP                           110        140        100        100        110
# PR                            80         80        100         80         80
# Edema                          0          1          0          0          0
# Weak Peripheral Pulse          N          N          N          N          N
# Lung rales                     N          N          N          N          N
# Systolic Murmur                N          N          N          N          Y
# Diastolic Murmur               N          N          N          Y          N
# Typical Chest Pain             0          1          1          0          0
# Dyspnea                        N          N          N          Y          Y
# Function Class                 0          0          0          3          2
# Atypical                       N          N          N          N          N
# Nonanginal                     N          N          N          Y          N
# Exertional CP                  N          N          N          N          N
# LowTH Ang                      N          N          N          N          N
# Q Wave                         0          0          0          0          0
# St Elevation                   0          0          0          0          0
# St Depression                  1          1          0          1          0
# Tinversion                     1          1          0          0          0
# LVH                            N          N          N          N          N
# Poor R Progression             N          N          N          N          N
# FBS                           90         80         85         78        104
# CR                           0.7        1.0        1.0        1.2        1.0
# TG                           250        309        103         63        170
# LDL                          155        121         70         55        110
# HDL                         30.0       36.0       45.0       27.0       50.0
# BUN                            8         30         17         30         16
# ESR                            7         26         10         76         27
# HB                          15.6       13.9       13.5       12.1       13.2
# K                            4.7        4.7        4.7        4.4        4.0
# Na                           141        156        139        142        140
# WBC                         5700       7700       7400      13000       9200
# Lymph                         39         38         38         18         55
# Neut                          52         55         60         72         39
# PLT                          261        165        230        742        274
# EF-TTE                        50         40         40         55         50
# Region RWMA                    0          4          2          0          0
# VHD                            N          N       mild     Severe     Severe
# Cath                         Cad        Cad        Cad     Normal     Normal

# %%
df.iloc[5:11 , :5 ]
# Out:
#     Age  Weight  Length    Sex        BMI
# 5    50      75     175   Male  24.489796
# 6    55      80     165   Male  29.384757
# 7    72      80     175   Male  26.122449
# 8    58      84     163  Fmale  31.615793
# 9    60      71     170   Male  24.567474
# 10   58      75     168   Male  26.573129

# %%
df.loc[[22,35,100,222] ,["Age","Diastolic Murmur"]]
# Out:
#      Age Diastolic Murmur
# 22    66                N
# 35    47                N
# 100   76                Y
# 222   62                N

# %%
df[["HTN","Current Smoker"]].value_counts()
# Out:
# HTN  Current Smoker
# 1    0                 152
# 0    0                  88
#      1                  36
# 1    1                  27
# dtype: int64

# %%
df[["HTN","EX-Smoker"]].value_counts()
# Out:
# HTN  EX-Smoker
# 1    0            172
# 0    0            121
# 1    1              7
# 0    1              3
# dtype: int64

# %%
df["Thyroid Disease"].value_counts()
# Out:
# N    296
# Y      7
# Name: Thyroid Disease, dtype: int64

# %%
BMI_group=pd.cut(df["BMI"],[0,18.5,24.9,41],labels=["Underweight","Healthy Weight", "Overweight"])
df["BMI_group"]=BMI_group
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ...   Na    WBC Lymph Neut  PLT EF-TTE Region RWMA  \
# 0            0   0  ...  141   5700    39   52  261     50           0
# 1            0   0  ...  156   7700    38   55  165     40           4
# 2            0   0  ...  139   7400    38   60  230     40           2
# 3            0   0  ...  142  13000    18   72  742     55           0
# 4            0   0  ...  140   9200    55   39  274     50           0
# ..         ...  ..  ...  ...    ...   ...  ...  ...    ...         ...
# 298          0   0  ...  146   8500    34   58  251     45           0
# 299          0   0  ...  139  11400    16   80  377     40           0
# 300          0   1  ...  140   9000    35   55  279     55           0
# 301          0   0  ...  141   3800    48   40  208     55           0
# 302          0   0  ...  147   6000    32   55  302     55           0
#
#         VHD    Cath       BMI_group
# 0         N     Cad      Overweight
# 1         N     Cad      Overweight
# 2      mild     Cad  Healthy Weight
# 3    Severe  Normal      Overweight
# 4    Severe  Normal      Overweight
# ..      ...     ...             ...
# 298       N     Cad      Overweight
# 299    mild  Normal      Overweight
# 300       N  Normal      Overweight
# 301       N  Normal      Overweight
# 302       N     Cad      Overweight
#
# [303 rows x 56 columns]

# %%
age_group=pd.cut(df["Age"],[0,10,18,50,150],labels=["kid","teen", "adult","old"])
df["Age_group"]=age_group
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ...    WBC Lymph Neut  PLT EF-TTE Region RWMA     VHD  \
# 0            0   0  ...   5700    39   52  261     50           0       N
# 1            0   0  ...   7700    38   55  165     40           4       N
# 2            0   0  ...   7400    38   60  230     40           2    mild
# 3            0   0  ...  13000    18   72  742     55           0  Severe
# 4            0   0  ...   9200    55   39  274     50           0  Severe
# ..         ...  ..  ...    ...   ...  ...  ...    ...         ...     ...
# 298          0   0  ...   8500    34   58  251     45           0       N
# 299          0   0  ...  11400    16   80  377     40           0    mild
# 300          0   1  ...   9000    35   55  279     55           0       N
# 301          0   0  ...   3800    48   40  208     55           0       N
# 302          0   0  ...   6000    32   55  302     55           0       N
#
#        Cath       BMI_group  Age_group
# 0       Cad      Overweight        old
# 1       Cad      Overweight        old
# 2       Cad  Healthy Weight        old
# 3    Normal      Overweight        old
# 4    Normal      Overweight      adult
# ..      ...             ...        ...
# 298     Cad      Overweight        old
# 299  Normal      Overweight        old
# 300  Normal      Overweight      adult
# 301  Normal      Overweight        old
# 302     Cad      Overweight        old
#
# [303 rows x 57 columns]

# %%
Na_rate=pd.cut(df["Na"],[0,136,145,1000],labels=["hyponatremia","normal", "hypernatremia"])
df["Na_rate"]= Na_rate
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ... Lymph Neut  PLT EF-TTE Region RWMA     VHD    Cath  \
# 0            0   0  ...    39   52  261     50           0       N     Cad
# 1            0   0  ...    38   55  165     40           4       N     Cad
# 2            0   0  ...    38   60  230     40           2    mild     Cad
# 3            0   0  ...    18   72  742     55           0  Severe  Normal
# 4            0   0  ...    55   39  274     50           0  Severe  Normal
# ..         ...  ..  ...   ...  ...  ...    ...         ...     ...     ...
# 298          0   0  ...    34   58  251     45           0       N     Cad
# 299          0   0  ...    16   80  377     40           0    mild  Normal
# 300          0   1  ...    35   55  279     55           0       N  Normal
# 301          0   0  ...    48   40  208     55           0       N  Normal
# 302          0   0  ...    32   55  302     55           0       N     Cad
#
#            Na_rate  K rate   K_rate
# 0           normal   normal   normal
# 1    hypernatremia   normal   normal
# 2           normal   normal   normal
# 3           normal   normal   normal
# 4           normal   normal   normal
# ..             ...      ...      ...
# 298  hypernatremia   normal   normal
# 299         normal   normal   normal
# 300         normal   normal   normal
# 301         normal   normal   normal
# 302  hypernatremia   normal   normal
#
# [303 rows x 58 columns]

# %%
WBC_range = df.WBC.max()-df.WBC.min()
WBC_range
# Out:
# 14300

# %%
df.groupby(["Sex"]).describe().T
# Out:
# Sex                     Fmale        Male
# Age         count  127.000000  176.000000
#             mean    59.456693   58.494318
#             std      9.857521   10.771389
#             min     36.000000   30.000000
#             25%     51.000000   50.000000
# ...                       ...         ...
# Region RWMA min      0.000000    0.000000
#             25%      0.000000    0.000000
#             50%      0.000000    0.000000
#             75%      0.000000    1.000000
#             max      4.000000    4.000000
#
# [272 rows x 2 columns]

# %%
df.groupby("Current Smoker").describe().T
# Out:
# Current Smoker              0          1
# Age         count  240.000000  63.000000
#             mean    59.662500  55.984127
#             std     10.252393  10.487307
#             min     30.000000  30.000000
#             25%     51.750000  48.000000
# ...                       ...        ...
# Region RWMA min      0.000000   0.000000
#             25%      0.000000   0.000000
#             50%      0.000000   0.000000
#             75%      1.000000   2.000000
#             max      4.000000   4.000000
#
# [264 rows x 2 columns]

# %%
a = df.groupby(["VHD"])
a.mean()
# Out:
# /var/folders/tz/bv94hgj91pz58fhx5qxg06pr0000gn/T/ipykernel_2059/603947438.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a.mean()
#                 Age     Weight      Length        BMI        DM       HTN  \
# VHD
# Moderate  60.370370  70.962963  165.444444  26.003311  0.370370  0.555556
# N         56.706897  76.577586  165.732759  27.915668  0.284483  0.525862
# Severe    57.000000  70.818182  162.181818  27.005524  0.000000  0.454545
# mild      60.476510  72.436242  163.979866  26.972343  0.315436  0.657718
#
#           Current Smoker  EX-Smoker        FH          BP  ...        ESR  \
# VHD                                                        ...
# Moderate        0.185185   0.111111  0.037037  128.148148  ...  20.185185
# N               0.267241   0.008621  0.250000  127.310345  ...  18.267241
# Severe          0.272727   0.000000  0.000000  122.272727  ...  20.727273
# mild            0.161074   0.040268  0.120805  132.093960  ...  20.167785
#
#                  HB         K          Na          WBC      Lymph       Neut  \
# VHD
# Moderate  13.251852  4.337037  140.629630  8196.296296  30.518519  62.518519
# N         13.154310  4.227586  141.301724  7324.137931  33.646552  59.034483
# Severe    13.290909  4.081818  140.909091  8772.727273  31.181818  61.545455
# mild      13.124832  4.224832  140.832215  7542.953020  31.859060  60.483221
#
#                  PLT     EF-TTE  Region RWMA
# VHD
# Moderate  212.370370  35.000000     1.370370
# N         220.431034  50.525862     0.370690
# Severe    271.181818  45.000000     0.181818
# mild      220.295302  47.046980     0.711409
#
# [4 rows x 34 columns]

# %%
df.agg([np.mean, np.sum ])
# Out:
# /var/folders/tz/bv94hgj91pz58fhx5qxg06pr0000gn/T/ipykernel_787/3717804937.py:1: FutureWarning: ['Sex', 'Obesity', 'CRF', 'CVA', 'Airway disease', 'Thyroid Disease', 'CHF', 'DLP', 'Weak Peripheral Pulse', 'Lung rales', 'Systolic Murmur', 'Diastolic Murmur', 'Dyspnea', 'Atypical', 'Nonanginal', 'Exertional CP', 'LowTH Ang', 'LVH', 'Poor R Progression', 'VHD', 'Cath', 'BMI_group', 'Age_group'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg([np.mean, np.sum ])
#               Age        Weight        Length  \
# mean     58.89769     73.831683    164.716172
# sum   17846.00000  22371.000000  49909.000000
#
#                                                     Sex          BMI  \
# mean                                                NaN    27.248339
# sum   MaleFmaleMaleFmaleFmaleMaleMaleMaleFmaleMaleMa...  8256.246674
#
#             DM         HTN  Current Smoker  EX-Smoker         FH  ...  \
# mean   0.29703    0.590759        0.207921   0.033003   0.158416  ...
# sum   90.00000  179.000000       63.000000  10.000000  48.000000  ...
#
#                 K          Na           WBC       Lymph          Neut  \
# mean     4.230693    140.9967  7.562046e+03    32.39934     60.148515
# sum   1281.900000  42722.0000  2.291300e+06  9817.00000  18225.000000
#
#                PLT        EF-TTE  Region RWMA  \
# mean    221.488449     47.231023     0.620462
# sum   67111.000000  14311.000000   188.000000
#
#                                                     VHD  \
# mean                                                NaN
# sum   NNmildSevereSevereNmildmildNNmildmildModeratem...
#
#                                                    Cath
# mean                                                NaN
# sum   CadCadCadNormalNormalCadCadCadNormalCadCadCadC...
#
# [2 rows x 55 columns]

# %%
df["PLT"].describe(percentiles = [0.05 , 0.40 , 0.95])
# Out:
# count    303.000000
# mean     221.488449
# std       60.796199
# min       25.000000
# 5%       159.100000
# 40%      196.800000
# 50%      210.000000
# 95%      330.000000
# max      742.000000
# Name: PLT, dtype: float64

# %%
df[df["PLT"]>df.PLT.quantile(0.75)].reset_index().T
# Out:
#                               0          1          2          3          4   \
# index                          0          3          4          6          7
# Age                           53         66         50         55         72
# Weight                        90         67         87         80         80
# Length                       175        158        153        165        175
# Sex                         Male      Fmale      Fmale       Male       Male
# BMI                    29.387755  26.838648  37.165193  29.384757  26.122449
# DM                             0          0          0          0          1
# HTN                            1          1          1          0          0
# Current Smoker                 1          0          0          0          1
# EX-Smoker                      0          0          0          1          0
# FH                             0          0          0          0          0
# Obesity                        Y          Y          Y          Y          Y
# CRF                            N          N          N          N          N
# CVA                            N          N          N          N          N
# Airway disease                 N          N          N          N          N
# Thyroid Disease                N          N          N          N          N
# CHF                            N          N          N          N          N
# DLP                            Y          N          N          N          Y
# BP                           110        100        110        110        130
# PR                            80         80         80         80         70
# Edema                          0          0          0          0          0
# Weak Peripheral Pulse          N          N          N          N          N
# Lung rales                     N          N          N          N          N
# Systolic Murmur                N          N          Y          Y          N
# Diastolic Murmur               N          Y          N          N          N
# Typical Chest Pain             0          0          0          1          1
# Dyspnea                        N          Y          Y          N          N
# Function Class                 0          3          2          0          0
# Atypical                       N          N          N          N          N
# Nonanginal                     N          Y          N          N          N
# Exertional CP                  N          N          N          N          N
# LowTH Ang                      N          N          N          N          N
# Q Wave                         0          0          0          1          0
# St Elevation                   0          0          0          1          0
# St Depression                  1          1          0          0          1
# Tinversion                     1          0          0          1          1
# LVH                            N          N          N          N          N
# Poor R Progression             N          N          N          N          N
# FBS                           90         78        104         80        130
# CR                           0.7        1.2        1.0        0.8        0.9
# TG                           250         63        170         83         80
# LDL                          155         55        110         85         90
# HDL                         30.0       27.0       50.0       34.0       55.0
# BUN                            8         30         16         12         19
# ESR                            7         76         27         38          4
# HB                          15.6       12.1       13.2       14.1       16.1
# K                            4.7        4.4        4.0        4.8        4.3
# Na                           141        142        140        139        142
# WBC                         5700      13000       9200       9400      12200
# Lymph                         39         18         55         58         25
# Neut                          52         72         39         33         74
# PLT                          261        742        274        292        410
# EF-TTE                        50         55         50         40         45
# Region RWMA                    0          0          0          4          4
# VHD                            N     Severe     Severe       mild       mild
# Cath                         Cad     Normal     Normal        Cad        Cad
# Na_rate                   normal     normal     normal     normal     normal
# K rate                    normal     normal     normal     normal     normal
# K_rate                    normal     normal     normal     normal     normal
#
#                               5          6             7              8   \
# index                          8          9            11             12
# Age                           58         60            80             70
# Weight                        84         71            67             70
# Length                       163        170           153            151
# Sex                        Fmale       Male         Fmale          Fmale
# BMI                    31.615793  24.567474      28.62147      30.700408
# DM                             0          1             0              1
# HTN                            0          0             1              1
# Current Smoker                 0          0             0              0
# EX-Smoker                      0          0             0              0
# FH                             0          0             0              0
# Obesity                        Y          N             Y              Y
# CRF                            N          N             N              N
# CVA                            N          N             N              N
# Airway disease                 N          N             N              N
# Thyroid Disease                N          N             N              N
# CHF                            N          N             N              N
# DLP                            N          N             Y              Y
# BP                            90        130           140            140
# PR                            50         70           100             84
# Edema                          0          0             0              0
# Weak Peripheral Pulse          N          N             N              N
# Lung rales                     N          N             N              N
# Systolic Murmur                N          N             N              Y
# Diastolic Murmur               N          N             N              N
# Typical Chest Pain             0          1             1              0
# Dyspnea                        Y          Y             N              N
# Function Class                 0          2             3              0
# Atypical                       N          N             N              Y
# Nonanginal                     Y          N             N              N
# Exertional CP                  N          N             N              N
# LowTH Ang                      N          N             N              N
# Q Wave                         0          0             0              0
# St Elevation                   0          0             0              0
# St Depression                  0          0             1              1
# Tinversion                     0          0             1              1
# LVH                            N          N             N              Y
# Poor R Progression             N          N             N              N
# FBS                           69        209            85            170
# CR                           0.6        1.3           1.3            1.0
# TG                            79         80           104            235
# LDL                           90         90           112            148
# HDL                         59.0       44.0          44.0           25.0
# BUN                           15         16            18             12
# ESR                            5          8            47             80
# HB                          11.6       13.9          10.0           12.3
# K                            3.4        4.6           4.3            4.3
# Na                           139        140           128            148
# WBC                         5100       4900         11000          11300
# Lymph                         49         55            31             25
# Neut                          50         42            66             70
# PLT                          370        380           290            380
# EF-TTE                        50         40            50             25
# Region RWMA                    0          2             3              4
# VHD                            N          N          mild       Moderate
# Cath                      Normal        Cad           Cad            Cad
# Na_rate                   normal     normal  hyponatremia  hypernatremia
# K rate                   problem     normal        normal         normal
# K_rate                   problem     normal        normal         normal
#
#                               9   ...         65         66         67  \
# index                         13  ...        288        292        294
# Age                           67  ...         67         57         64
# Weight                        63  ...         68         85         70
# Length                       154  ...        150        174        175
# Sex                        Fmale  ...      Fmale       Male       Male
# BMI                    26.564345  ...  30.222222  28.075043  22.857143
# DM                             1  ...          0          1          1
# HTN                            1  ...          1          1          0
# Current Smoker                 0  ...          0          0          1
# EX-Smoker                      0  ...          0          0          0
# FH                             0  ...          0          0          0
# Obesity                        Y  ...          Y          Y          N
# CRF                            N  ...          N          N          N
# CVA                            N  ...          N          N          N
# Airway disease                 N  ...          N          N          N
# Thyroid Disease                N  ...          N          N          N
# CHF                            N  ...          N          N          N
# DLP                            Y  ...          Y          Y          Y
# BP                           150  ...        140        140        100
# PR                            74  ...         70         80         80
# Edema                          0  ...          0          0          0
# Weak Peripheral Pulse          N  ...          N          N          N
# Lung rales                     N  ...          N          N          N
# Systolic Murmur                N  ...          N          Y          Y
# Diastolic Murmur               N  ...          N          N          N
# Typical Chest Pain             0  ...          0          0          0
# Dyspnea                        Y  ...          N          N          Y
# Function Class                 2  ...          0          0          3
# Atypical                       Y  ...          Y          N          Y
# Nonanginal                     N  ...          N          N          N
# Exertional CP                  N  ...          N          N          N
# LowTH Ang                      N  ...          N          N          N
# Q Wave                         0  ...          0          0          0
# St Elevation                   0  ...          0          0          0
# St Depression                  0  ...          0          0          1
# Tinversion                     1  ...          0          0          1
# LVH                            N  ...          Y          Y          N
# Poor R Progression             N  ...          N          N          N
# FBS                          183  ...         98        190        112
# CR                           1.1  ...        0.7        1.2        0.8
# TG                           358  ...         93         96        147
# LDL                          118  ...         92        112         82
# HDL                         32.0  ...       47.0       30.0       25.0
# BUN                           20  ...         21         17         20
# ESR                           18  ...         24         11         67
# HB                          14.3  ...       13.8       15.6       12.3
# K                            4.5  ...        4.7        3.9        3.7
# Na                           139  ...        144        142        140
# WBC                         8100  ...       6800       7800      11300
# Lymph                         31  ...         33         38         23
# Neut                          65  ...         57         49         70
# PLT                          254  ...        301        301        266
# EF-TTE                        55  ...         50         60         50
# Region RWMA                    2  ...          0          0          0
# VHD                         mild  ...          N       mild   Moderate
# Cath                         Cad  ...        Cad     Normal        Cad
# Na_rate                   normal  ...     normal     normal     normal
# K rate                    normal  ...     normal     normal     normal
# K_rate                    normal  ...     normal     normal     normal
#
#                               68         69         70             71  \
# index                        295        296        297            298
# Age                           62         42         30             58
# Weight                        48         63        100             84
# Length                       152        163        172            168
# Sex                        Fmale       Male       Male           Male
# BMI                    20.775623  23.711845  33.802055      29.761905
# DM                             0          0          0              0
# HTN                            1          0          0              0
# Current Smoker                 0          0          1              0
# EX-Smoker                      0          0          0              0
# FH                             0          1          1              0
# Obesity                        N          N          Y              Y
# CRF                            N          N          N              N
# CVA                            N          N          N              N
# Airway disease                 N          N          N              N
# Thyroid Disease                N          N          N              N
# CHF                            N          N          N              N
# DLP                            Y          N          N              N
# BP                           180        120        110            100
# PR                            80         70         60             76
# Edema                          0          0          0              0
# Weak Peripheral Pulse          N          N          N              N
# Lung rales                     N          N          N              N
# Systolic Murmur                N          N          N              N
# Diastolic Murmur               N          N          N              N
# Typical Chest Pain             0          0          0              1
# Dyspnea                        Y          Y          N              N
# Function Class                 0          0          0              0
# Atypical                       N          Y          Y              N
# Nonanginal                     Y          N          N              N
# Exertional CP                  N          N          N              N
# LowTH Ang                      N          N          N              N
# Q Wave                         0          0          0              0
# St Elevation                   0          0          0              0
# St Depression                  0          0          0              0
# Tinversion                     0          0          0              0
# LVH                            N          N          N              N
# Poor R Progression             N          N          N              N
# FBS                           94        202         83             92
# CR                           0.8        1.0        1.0            1.0
# TG                           100        204        205            112
# LDL                           78        120         97            115
# HDL                         41.0       41.0       53.0           44.0
# BUN                           22         19         20             13
# ESR                           49          3         16             13
# HB                           9.0       11.0       13.1           12.3
# K                            3.6        3.9        4.0            4.8
# Na                           143        141        143            146
# WBC                         4800       8400       9100           8500
# Lymph                         30         45         39             34
# Neut                          56         47         60             58
# PLT                          360        292        294            251
# EF-TTE                        45         50         55             45
# Region RWMA                    0          0          1              0
# VHD                         mild       mild          N              N
# Cath                      Normal     Normal     Normal            Cad
# Na_rate                   normal     normal     normal  hypernatremia
# K rate                   problem     normal     normal         normal
# K_rate                   problem     normal     normal         normal
#
#                               72         73             74
# index                        299        300            302
# Age                           55         48             56
# Weight                        64         77             85
# Length                       152        160            170
# Sex                        Fmale      Fmale          Fmale
# BMI                    27.700831  30.078125      29.411765
# DM                             0          0              0
# HTN                            0          1              1
# Current Smoker                 0          0              1
# EX-Smoker                      0          0              0
# FH                             0          1              0
# Obesity                        Y          Y              Y
# CRF                            N          N              N
# CVA                            N          N              N
# Airway disease                 N          N              N
# Thyroid Disease                N          N              N
# CHF                            N          N              N
# DLP                            N          N              N
# BP                           100        130            120
# PR                            60         70             80
# Edema                          0          0              0
# Weak Peripheral Pulse          N          N              N
# Lung rales                     N          N              N
# Systolic Murmur                Y          N              N
# Diastolic Murmur               N          N              N
# Typical Chest Pain             0          0              1
# Dyspnea                        Y          N              N
# Function Class                 0          0              0
# Atypical                       Y          N              N
# Nonanginal                     N          Y              N
# Exertional CP                  N          N              N
# LowTH Ang                      N          N              N
# Q Wave                         0          0              0
# St Elevation                   0          0              0
# St Depression                  0          0              0
# Tinversion                     0          0              1
# LVH                            N          N              N
# Poor R Progression             N          N              N
# FBS                           86         83             78
# CR                           0.9        1.0            0.7
# TG                           111         93            139
# LDL                           40        112            124
# HDL                         23.0       42.0           34.0
# BUN                           23         13             16
# ESR                            3         20             13
# HB                          12.4       12.8           14.7
# K                            4.0        4.0            4.4
# Na                           139        140            147
# WBC                        11400       9000           6000
# Lymph                         16         35             32
# Neut                          80         55             55
# PLT                          377        279            302
# EF-TTE                        40         55             55
# Region RWMA                    0          0              0
# VHD                         mild          N              N
# Cath                      Normal     Normal            Cad
# Na_rate                   normal     normal  hypernatremia
# K rate                    normal     normal         normal
# K_rate                    normal     normal         normal
#
# [59 rows x 75 columns]

# %%
sns.histplot(data =[df["LDL"],df["HDL"]], stat = "percent" )
# Out:
# <Axes: ylabel='Percent'>

# %%
df["K_rate "] = ["normal" if 3.6<x<5.2 else "problem" for x in df['K']]
df
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 0     53      90     175   Male  29.387755   0    1               1
# 1     67      70     157  Fmale  28.398718   0    1               0
# 2     54      54     164   Male  20.077335   0    0               1
# 3     66      67     158  Fmale  26.838648   0    1               0
# 4     50      87     153  Fmale  37.165193   0    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 298   58      84     168   Male  29.761905   0    0               0
# 299   55      64     152  Fmale  27.700831   0    0               0
# 300   48      77     160  Fmale  30.078125   0    1               0
# 301   57      90     159  Fmale  35.599858   1    0               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ... Lymph Neut  PLT EF-TTE Region RWMA     VHD    Cath  \
# 0            0   0  ...    39   52  261     50           0       N     Cad
# 1            0   0  ...    38   55  165     40           4       N     Cad
# 2            0   0  ...    38   60  230     40           2    mild     Cad
# 3            0   0  ...    18   72  742     55           0  Severe  Normal
# 4            0   0  ...    55   39  274     50           0  Severe  Normal
# ..         ...  ..  ...   ...  ...  ...    ...         ...     ...     ...
# 298          0   0  ...    34   58  251     45           0       N     Cad
# 299          0   0  ...    16   80  377     40           0    mild  Normal
# 300          0   1  ...    35   55  279     55           0       N  Normal
# 301          0   0  ...    48   40  208     55           0       N  Normal
# 302          0   0  ...    32   55  302     55           0       N     Cad
#
#            Na_rate  K rate   K_rate
# 0           normal   normal   normal
# 1    hypernatremia   normal   normal
# 2           normal   normal   normal
# 3           normal   normal   normal
# 4           normal   normal   normal
# ..             ...      ...      ...
# 298  hypernatremia   normal   normal
# 299         normal   normal   normal
# 300         normal   normal   normal
# 301         normal   normal   normal
# 302  hypernatremia   normal   normal
#
# [303 rows x 58 columns]

# %%
df["K_rate"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'K_rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df["K_rate"].describe()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'K_rate'

# %%
test =df[(df.Age > 55 ) & (df.HTN == 1 )]
test
# Out:
#      Age  Weight  Length    Sex        BMI  DM  HTN  Current Smoker  \
# 1     67      70     157  Fmale  28.398718   0    1               0
# 3     66      67     158  Fmale  26.838648   0    1               0
# 10    58      75     168   Male  26.573129   0    1               0
# 11    80      67     153  Fmale  28.621470   0    1               0
# 12    70      70     151  Fmale  30.700408   1    1               0
# ..   ...     ...     ...    ...        ...  ..  ...             ...
# 284   70      70     161  Fmale  27.005131   0    1               0
# 288   67      68     150  Fmale  30.222222   0    1               0
# 292   57      85     174   Male  28.075043   1    1               0
# 295   62      48     152  Fmale  20.775623   0    1               0
# 302   56      85     170  Fmale  29.411765   0    1               1
#
#      EX-Smoker  FH  ... Lymph Neut  PLT EF-TTE Region RWMA       VHD    Cath  \
# 1            0   0  ...    38   55  165     40           4         N     Cad
# 3            0   0  ...    18   72  742     55           0    Severe  Normal
# 10           1   0  ...    44   52  201     50           0      mild     Cad
# 11           0   0  ...    31   66  290     50           3      mild     Cad
# 12           0   0  ...    25   70  380     25           4  Moderate     Cad
# ..         ...  ..  ...   ...  ...  ...    ...         ...       ...     ...
# 284          0   0  ...    31   57  182     50           0      mild  Normal
# 288          0   0  ...    33   57  301     50           0         N     Cad
# 292          0   0  ...    38   49  301     60           0      mild  Normal
# 295          0   0  ...    30   56  360     45           0      mild  Normal
# 302          0   0  ...    32   55  302     55           0         N     Cad
#
#            Na_rate  K rate   K_rate
# 1    hypernatremia   normal   normal
# 3           normal   normal   normal
# 10          normal   normal   normal
# 11    hyponatremia   normal   normal
# 12   hypernatremia   normal   normal
# ..             ...      ...      ...
# 284         normal   normal   normal
# 288         normal   normal   normal
# 292         normal   normal   normal
# 295         normal  problem  problem
# 302  hypernatremia   normal   normal
#
# [116 rows x 58 columns]

# %%
df["age&HTN "] = ["yes" if x=test else "no" for x in test]
# Out:
#   Cell In[91], line 1
#     df["age&HTN "] = ["yes" if x=test else "no" for x in test]
#                       ^
# SyntaxError: expected 'else' after 'if' expression
